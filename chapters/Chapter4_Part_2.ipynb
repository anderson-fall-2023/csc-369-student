# %% [markdown]
# # Chapter 4 - Part 2
#
# Paul E. Anderson

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
home = str(Path.home()) # all other paths are relative to this path. 

import pandas as pd

# %%
from pyspark import SparkConf
from pyspark.context import SparkContext

sc = SparkContext.getOrCreate(SparkConf().setMaster("local[*]"))
# Out:
# 23/10/31 02:06:42 WARN Utils: Your hostname, classes resolves to a loopback address: 127.0.1.1; using 192.168.122.111 instead (on interface enp1s0)
# 23/10/31 02:06:42 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/10/31 02:06:43 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/10/31 02:06:43 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %% [markdown]
# Creating an RDD from a Python object is useful, but most of our data will be in files or databases. Spark provides a few functions to read files:
#
# * ``sc.textFile(path)``
# * ``sc.wholeTextFiles(path)``

# %% [markdown]
# ``textFile`` takes a string argument that is the path to the file or files to be read. Both of these can read multiple files into an RDD/PairRDD.
#
# For example:
#
# * ``sc.textFile(path)`` - returns an RDD with each line as an element
# * ``sc.wholeTextFiles(path)`` - returns a PairRDD object where the key is file path and the value is the contents of the file.

# %% [markdown]
# ``textFile`` will split the data into chuncks of 32MB.
#
# This is advantagous from a memory perspective, but the ordering of the lines is lost, if the order should be preserved then wholeTextFiles should be used.
#
# ``wholeTextFiles`` will read the complete content of a file at once. Each file will be handled by one core and the data for each file will be one a single machine making it harder to distribute the load.

# %%
data = ["Project Gutenberg’s",
        "Alice’s Adventures in Wonderland",
        "Project Gutenberg’s",
        "Adventures in Wonderland",
        "Project Gutenberg’s"]
rdd=sc.parallelize(data) # distributes data
for element in rdd.collect():
    print(element)
# Out:
# Project Gutenberg’s
# Alice’s Adventures in Wonderland
# Project Gutenberg’s
# Adventures in Wonderland
# Project Gutenberg’s

# %% [markdown]
# **Exercise 2:** Create a function that returns the word frequency of each word in an RDD.

# %%
def word_freq(rdd):
    output = []
    # Your solution here
    return output

# %%
word_freq(rdd)
# Out:
# [('Gutenberg’s', 3),
#  ('Adventures', 2),
#  ('Wonderland', 2),
#  ('Alice’s', 1),
#  ('in', 2),
#  ('Project', 3)]

# %% [markdown]
# **Exercise 3:**
#
# Write a function that reads all of the books into a single RDD. Call this function ``load_rdd_all_books``.

# %%
def load_rdd_all_books(sc,dir):
    lines = None
    return lines

# %%
all_books_rdd = load_rdd_all_books(sc,f"file:{home}/csc-369-student/data/gutenberg")
all_books_rdd
# Out:
# file:/home/jupyter-pander14/csc-369-student/data/gutenberg/*.txt MapPartitionsRDD[33] at textFile at NativeMethodAccessorImpl.java:0

# %% [markdown]
# **Problem 1:** Apply your word frequency function to the all_books_rdd.

# %%
output = word_freq(all_books_rdd)
# Your solution here
output[:10]
# Out:
# [('', 480179),
#  ('have', 43375),
#  ('Æt.', 6),
#  ('LITERATURE', 2),
#  ('XIX.', 28),
#  ('HURTFUL?', 2),
#  ('government', 462),
#  ('environment', 15),
#  ('dedicates', 5),
#  ('pleasure,', 302)]

# %%
# We can use pandas to print it in a readable way
pd.DataFrame(output,columns=['Word','Frequency']).sort_values(by="Frequency")
# Out:
#                           Word  Frequency
# 183816  water.—_Anglo-Indian._          1
# 214278                Hareton?          1
# 214279                 hoile’s          1
# 214280             disordered:          1
# 214281       sneeringly,—“Will          1
# ...                        ...        ...
# 195628                      to     243237
# 146853                      of     253400
# 4800                       and     290833
# 205473                     the     458876
# 0                                  480179
#
# [367634 rows x 2 columns]

# %% [markdown]
# **Exercise 4:** Use ``wholeTextFiles`` and the ``map`` function to return the word counts for each book individually. Call this function book_word_counts. Do not use your previous function word_freq as that will not work in this case without modifications.

# %%
# This is a helper function you can use

def count_words(content):
    counts = {}
    for line in content.split("\n"):
        words = line.split(" ")
        for word in words:
            if word not in counts:
                counts[word] = 0
            counts[word] += 1
    return counts

# %%
def book_word_counts(sc,dir):
    res = None
    return res

# %%
res = book_word_counts(sc,f"file:{home}/csc-369-student/data/gutenberg")
res[0] # One book
# Out:
# ('1232-0.txt',
#  {'\ufeffThe': 1,
#   'Project': 65,
#   'Gutenberg': 19,
#   'eBook': 5,
#   'of': 1645,
#   'The': 89,
#   'Prince,': 1,
#   'by': 452,
#   'Nicolo': 11,
#   'Machiavelli\r': 6,
#   '\r': 588,
#   'This': 51,
#   'is': 398,
#   'for': 377,
#   'the': 2641,
#   'use': 24,
#   'anyone': 3,
#   'anywhere': 2,
#   'in': 871,
#   'United': 12,
#   'States': 8,
#   'and\r': 167,
#   'most': 40,
#   'other': 114,
#   'parts': 4,
#   'world': 9,
#   'at': 191,
#   'no': 101,
#   'cost': 2,
#   'and': 1600,
#   'with': 447,
#   'almost': 9,
#   'restrictions\r': 1,
#   'whatsoever.': 2,
#   'You': 14,
#   'may': 100,
#   'copy': 8,
#   'it,': 41,
#   'give': 27,
#   'it': 425,
#   'away': 19,
#   'or': 239,
#   're-use': 2,
#   'under': 69,
#   'terms\r': 2,
#   'License': 8,
#   'included': 3,
#   'this': 244,
#   'online': 4,
#   'at\r': 11,
#   'www.gutenberg.org.': 2,
#   'If': 23,
#   'you': 179,
#   'are': 256,
#   'not': 438,
#   'located': 7,
#   'States,': 3,
#   'you\r': 9,
#   'will': 183,
#   'have': 344,
#   'to': 1924,
#   'check': 5,
#   'laws': 16,
#   'country': 26,
#   'where': 40,
#   'before\r': 2,
#   'using': 9,
#   'eBook.\r': 2,
#   'Title:': 1,
#   'Prince\r': 2,
#   'Author:': 1,
#   'Translator:': 1,
#   'W.': 2,
#   'K.': 2,
#   'Marriott\r': 2,
#   'Release': 1,
#   'Date:': 1,
#   'March,': 1,
#   '1998': 1,
#   '[eBook': 1,
#   '#1232]\r': 1,
#   '[Most': 1,
#   'recently': 3,
#   'updated:': 1,
#   'January': 2,
#   '2,': 1,
#   '2021]\r': 1,
#   'Language:': 1,
#   'English\r': 1,
#   'Character': 1,
#   'set': 21,
#   'encoding:': 1,
#   'UTF-8\r': 1,
#   'Produced': 1,
#   'by:': 1,
#   'John': 1,
#   'Bickers,': 1,
#   'David': 3,
#   'Widger': 1,
#   'Others\r': 1,
#   '***': 2,
#   'START': 1,
#   'OF': 34,
#   'THE': 43,
#   'PROJECT': 4,
#   'GUTENBERG': 3,
#   'EBOOK': 2,
#   'PRINCE': 6,
#   '***\r': 2,
#   'Translated': 1,
#   'Contents\r': 1,
#   '': 289,
#   'INTRODUCTION\r': 2,
#   'YOUTH': 2,
#   'Æt.': 6,
#   '1-25—1469-94\r': 2,
#   'OFFICE': 2,
#   '25-43—1494-1512\r': 2,
#   'LITERATURE': 2,
#   'AND': 28,
#   'DEATH': 2,
#   '43-58—1512-27\r': 2,
#   'MAN': 2,
#   'HIS': 4,
#   'WORKS\r': 2,
#   'DEDICATION\r': 2,
#   'PRINCE\r': 2,
#   'CHAPTER': 52,
#   'I.': 1,
#   'HOW': 10,
#   'MANY': 6,
#   'KINDS': 4,
#   'PRINCIPALITIES': 10,
#   'THERE': 4,
#   'ARE,': 3,
#   'BY': 16,
#   'WHAT': 4,
#   'MEANS': 2,
#   'THEY': 4,
#   'ARE': 10,
#   'ACQUIRED\r': 2,
#   'II.': 1,
#   'CONCERNING': 32,
#   'HEREDITARY': 2,
#   'PRINCIPALITIES\r': 6,
#   'III.': 1,
#   'MIXED': 4,
#   'IV.': 1,
#   'WHY': 4,
#   'KINGDOM': 2,
#   'DARIUS,': 2,
#   'CONQUERED': 2,
#   'ALEXANDER,': 2,
#   'DID': 2,
#   'NOT': 3,
#   'REBEL': 1,
#   'AGAINST': 2,
#   'SUCCESSORS': 2,
#   'ALEXANDER': 2,
#   'AT': 2,
#   'DEATH\r': 2,
#   'V.': 2,
#   'WAY': 6,
#   'TO': 15,
#   'GOVERN': 2,
#   'CITIES': 2,
#   'OR': 12,
#   'WHICH': 16,
#   'LIVED': 2,
#   'UNDER': 2,
#   'THEIR': 4,
#   'OWN': 4,
#   'LAWS': 2,
#   'BEFORE': 3,
#   'WERE': 2,
#   'ANNEXED\r': 2,
#   'VI.': 3,
#   'NEW': 4,
#   'ACQUIRED': 4,
#   'ONE’S': 4,
#   'ARMS': 4,
#   'ABILITY\r': 2,
#   'VII.': 2,
#   'EITHER': 2,
#   'OTHERS': 2,
#   'GOOD': 2,
#   'FORTUNE\r': 2,
#   'VIII.': 1,
#   'THOSE': 2,
#   'WHO': 2,
#   'HAVE': 5,
#   'OBTAINED': 2,
#   'A': 21,
#   'PRINCIPALITY': 2,
#   'WICKEDNESS\r': 2,
#   'IX.': 1,
#   'CIVIL': 2,
#   'PRINCIPALITY\r': 2,
#   'X.': 1,
#   'IN': 7,
#   'STRENGTH': 2,
#   'ALL': 2,
#   'OUGHT': 2,
#   'BE': 6,
#   'MEASURED\r': 2,
#   'XI.': 1,
#   'ECCLESIASTICAL': 2,
#   'XII.': 1,
#   'SOLDIERY': 2,
#   'MERCENARIES\r': 2,
#   'XIII.': 1,
#   'AUXILIARIES,': 2,
#   'SOLDIERY,': 2,
#   'OWN\r': 2,
#   'XIV.': 1,
#   'THAT': 6,
#   'CONCERNS': 2,
#   'ON': 2,
#   'SUBJECT': 2,
#   'WAR\r': 2,
#   'XV.': 1,
#   'THINGS': 4,
#   'FOR': 5,
#   'MEN,': 2,
#   'ESPECIALLY': 2,
#   'PRINCES,': 2,
#   'PRAISED': 2,
#   'BLAMED\r': 2,
#   'XVI.': 1,
#   'LIBERALITY': 2,
#   'MEANNESS\r': 2,
#   'XVII.': 1,
#   'CRUELTY': 2,
#   'CLEMENCY,': 2,
#   'WHETHER': 2,
#   'IT': 2,
#   'IS': 2,
#   'BETTER': 2,
#   'LOVED': 1,
#   'THAN': 2,
#   'FEARED\r': 2,
#   'XVIII.': 1,
#   'PRINCES': 6,
#   'SHOULD': 8,
#   'KEEP': 2,
#   'FAITH\r': 2,
#   'XIX.': 1,
#   'ONE': 2,
#   'AVOID': 2,
#   'BEING': 2,
#   'DESPISED': 2,
#   'HATED\r': 2,
#   'XX.': 1,
#   'FORTRESSES,': 2,
#   'OTHER': 3,
#   'OFTEN': 2,
#   'RESORT,': 1,
#   'ADVANTAGEOUS': 2,
#   'HURTFUL?\r': 2,
#   'XXI.': 1,
#   'CONDUCT': 2,
#   'HIMSELF': 2,
#   'SO': 2,
#   'AS': 2,
#   'GAIN': 2,
#   'RENOWN\r': 2,
#   'XXII.': 1,
#   'SECRETARIES': 2,
#   'PRINCES\r': 2,
#   'XXIII.': 1,
#   'FLATTERERS': 2,
#   'AVOIDED\r': 2,
#   'XXIV.': 1,
#   'ITALY': 4,
#   'LOST': 2,
#   'STATES\r': 2,
#   'XXV.': 1,
#   'FORTUNE': 2,
#   'CAN': 2,
#   'EFFECT': 2,
#   'HUMAN': 2,
#   'AFFAIRS': 2,
#   'WITHSTAND': 2,
#   'HER\r': 2,
#   'XXVI.': 1,
#   'AN': 2,
#   'EXHORTATION': 2,
#   'LIBERATE': 2,
#   'FROM': 2,
#   'BARBARIANS\r': 2,
#   'DESCRIPTION': 2,
#   'METHODS': 2,
#   'ADOPTED': 2,
#   'DUKE': 4,
#   'VALENTINO': 2,
#   'WHEN': 2,
#   'MURDERING': 1,
#   'VITELLOZZO': 2,
#   'VITELLI,': 2,
#   'OLIVEROTTO': 2,
#   'DA': 2,
#   'FERMO,': 2,
#   'SIGNOR': 2,
#   'PAGOLO,': 2,
#   'DI': 2,
#   'GRAVINA': 2,
#   'ORSINI\r': 2,
#   'LIFE': 2,
#   'CASTRUCCIO': 3,
#   'CASTRACANI': 3,
#   'LUCCA\r': 2,
#   '_': 1,
#   'Machiavelli,': 11,
#   'born': 25,
#   'Florence': 27,
#   'on': 169,
#   '3rd': 2,
#   'May': 4,
#   '1469.': 2,
#   'From': 9,
#   '1494': 3,
#   'to\r': 150,
#   '1512': 2,
#   'held': 22,
#   'an': 79,
#   'official': 5,
#   'post': 1,
#   'which': 296,
#   'diplomatic\r': 1,
#   'missions': 1,
#   'various': 6,
#   'European': 3,
#   'courts.': 1,
#   'Imprisoned': 1,
#   'Florence,': 9,
#   '1512;\r': 1,
#   'later': 4,
#   'exiled': 6,
#   'returned': 8,
#   'San': 17,
#   'Casciano.': 1,
#   'Died': 1,
#   '22nd\r': 1,
#   'June': 4,
#   '1527._\r': 1,
#   'Machiavelli': 31,
#   'was': 348,
#   'He': 65,
#   'the\r': 316,
#   'second': 10,
#   'son': 17,
#   'Bernardo': 1,
#   'di': 21,
#   'a': 671,
#   'lawyer': 1,
#   'some': 61,
#   'repute,\r': 1,
#   'Bartolommea': 1,
#   'Stefano': 6,
#   'Nelli,': 1,
#   'his': 556,
#   'wife.': 1,
#   'Both': 1,
#   'parents': 1,
#   'were\r': 22,
#   'members': 4,
#   'old': 21,
#   'Florentine': 16,
#   'nobility.\r': 1,
#   'His': 6,
#   'life': 18,
#   'falls': 3,
#   'naturally': 3,
#   'into': 73,
#   'three': 7,
#   'periods,': 2,
#   'each': 18,
#   'singularly\r': 1,
#   'enough': 12,
#   'constitutes': 1,
#   'distinct': 2,
#   'important': 7,
#   'era': 1,
#   'history': 2,
#   'of\r': 127,
#   'Florence.': 3,
#   'youth': 6,
#   'concurrent': 1,
#   'greatness': 11,
#   'as': 285,
#   'an\r': 9,
#   'Italian': 11,
#   'power': 25,
#   'guidance': 1,
#   'Lorenzo': 4,
#   'de’': 5,
#   'Medici,': 5,
#   'Il': 5,
#   'Magnifico.\r': 1,
#   'downfall': 1,
#   'Medici': 10,
#   'occurred': 4,
#   '1494,': 1,
#   'year\r': 2,
#   'entered': 9,
#   'public': 8,
#   'service.': 1,
#   'During': 3,
#   'career\r': 1,
#   'free': 10,
#   'government': 10,
#   'Republic,': 4,
#   'lasted\r': 1,
#   'until': 16,
#   '1512,': 2,
#   'when': 147,
#   'power,': 9,
#   'lost': 18,
#   'his\r': 73,
#   'office.': 1,
#   'again': 11,
#   'ruled': 9,
#   'from': 204,
#   '1527,': 2,
#   'they\r': 47,
#   'were': 167,
#   'once': 28,
#   'more': 134,
#   'driven': 15,
#   'out.': 3,
#   'period': 2,
#   'Machiavelli’s\r': 2,
#   'literary': 4,
#   'activity': 1,
#   'increasing': 4,
#   'influence;': 1,
#   'but': 190,
#   'he': 773,
#   'died,': 5,
#   'within': 13,
#   'few\r': 4,
#   'weeks': 2,
#   'expulsion': 2,
#   '22nd': 2,
#   'fifty-eighth': 1,
#   'year,': 2,
#   'without': 68,
#   'having': 90,
#   'regained': 2,
#   'office.\r': 2,
#   '—': 3,
#   'Although': 6,
#   'there': 95,
#   'little': 32,
#   'recorded': 1,
#   'those': 170,
#   'days': 12,
#   'so': 177,
#   'well': 47,
#   'known': 11,
#   'that': 631,
#   'early': 3,
#   'environment': 1,
#   'representative': 1,
#   'citizen': 6,
#   'be': 414,
#   'easily': 15,
#   'imagined.': 1,
#   'has': 150,
#   'been\r': 22,
#   'described': 3,
#   'city': 21,
#   'two': 50,
#   'opposite': 7,
#   'currents': 1,
#   'life,': 6,
#   'one': 244,
#   'directed': 3,
#   'by\r': 46,
#   'fervent': 1,
#   'austere': 1,
#   'Savonarola,': 2,
#   'splendour-loving\r': 1,
#   'Lorenzo.': 1,
#   'Savonarola’s': 1,
#   'influence': 2,
#   'upon': 45,
#   'young': 6,
#   'must': 37,
#   'have\r': 41,
#   'been': 137,
#   'slight,': 1,
#   'although': 36,
#   'time': 69,
#   'wielded': 1,
#   'immense': 4,
#   'over': 21,
#   'fortunes': 6,
#   'only': 85,
#   'furnished': 1,
#   'subject': 13,
#   'a\r': 83,
#   'gibe': 1,
#   '_The': 16,
#   'Prince_,': 6,
#   'cited': 2,
#   'example': 8,
#   'unarmed\r': 1,
#   'prophet': 1,
#   'who': 306,
#   'came': 33,
#   'bad': 12,
#   'end.': 1,
#   'Whereas': 1,
#   'magnificence': 1,
#   'Medicean\r': 1,
#   'rule': 15,
#   'during': 12,
#   'appeared': 14,
#   'impressed': 1,
#   'strongly,': 1,
#   'frequently': 2,
#   'recurs': 1,
#   'writings,': 1,
#   'Lorenzo’s': 1,
#   'grandson': 1,
#   'dedicates': 1,
#   'Prince_.\r': 2,
#   '“History': 5,
#   'Florence,”': 3,
#   'gives': 2,
#   'us': 16,
#   'picture': 1,
#   'men': 118,
#   'among': 25,
#   'whom': 67,
#   'passed.': 1,
#   'writes:': 2,
#   '“They': 1,
#   'freer\r': 1,
#   'than': 112,
#   'their': 234,
#   'forefathers': 1,
#   'dress': 1,
#   'living,': 1,
#   'spent': 3,
#   'other\r': 17,
#   'kinds': 3,
#   'excesses,': 1,
#   'consuming': 1,
#   'money': 8,
#   'idleness,': 1,
#   'gaming,\r': 1,
#   'women;': 1,
#   'chief': 3,
#   'aim': 5,
#   'appear': 13,
#   'dressed': 1,
#   'speak': 11,
#   'with\r': 39,
#   'wit': 3,
#   'acuteness,': 2,
#   'whilst': 36,
#   'could': 69,
#   'wound': 2,
#   'others': 41,
#   'cleverly\r': 1,
#   'thought': 11,
#   'wisest.”': 1,
#   'In': 40,
#   'letter': 4,
#   'Guido,': 1,
#   'shows': 2,
#   'why': 4,
#   'should': 116,
#   'avail': 3,
#   'itself': 5,
#   'its': 52,
#   'opportunities': 4,
#   'study,': 3,
#   'leads': 6,
#   'infer': 1,
#   'own': 80,
#   'had': 263,
#   'occupied.': 1,
#   'writes:\r': 1,
#   '“I': 4,
#   'received': 19,
#   'your': 43,
#   'letter,': 1,
#   'given': 25,
#   'me': 22,
#   'greatest': 11,
#   'pleasure,\r': 1,
#   'especially': 15,
#   'because': 131,
#   'tell': 4,
#   'quite': 9,
#   'restored': 5,
#   'health,': 3,
#   'than\r': 12,
#   'I': 194,
#   'better': 20,
#   'news;': 1,
#   'if': 145,
#   'God': 15,
#   'grant': 1,
#   'you,': 15,
#   'me,': 4,
#   'hope': 13,
#   'make': 69,
#   'good': 55,
#   'man': 52,
#   'willing': 14,
#   'do': 84,
#   'your\r': 11,
#   'share.”': 1,
#   'Then,': 1,
#   'writing': 4,
#   'new': 61,
#   'patron,': 3,
#   'continues:': 1,
#   '“This': 1,
#   'turn\r': 2,
#   'out': 65,
#   'necessary': 50,
#   'study;': 2,
#   'since,': 1,
#   'then,\r': 1,
#   'longer': 9,
#   'excuse': 6,
#   'illness,': 1,
#   'take': 51,
#   'pains': 1,
#   'study': 5,
#   'letters\r': 1,
#   'music,': 1,
#   'see': 23,
#   'what': 60,
#   'honour': 7,
#   'done': 16,
#   'skill': 4,
#   'I\r': 13,
#   'have.': 1,
#   'Therefore,': 23,
#   'my': 30,
#   'son,': 5,
#   'wish': 37,
#   'please': 6,
#   'bring': 17,
#   'success\r': 1,
#   'yourself,': 2,
#   'right': 7,
#   'help\r': 2,
#   'help': 17,
#   'yourself.”\r': 1,
#   'Machiavelli’s': 10,
#   'service': 3,
#   'Republic': 2,
#   'flourished,': 1,
#   'stated': 5,
#   'above,': 10,
#   'return': 11,
#   '1512.': 2,
#   'After\r': 3,
#   'serving': 2,
#   'four': 12,
#   'years': 13,
#   'offices': 1,
#   'appointed\r': 1,
#   'Chancellor': 1,
#   'Secretary': 1,
#   'Second': 3,
#   'Chancery,': 1,
#   'Ten': 1,
#   'Liberty': 2,
#   'Peace.': 1,
#   'Here': 6,
#   'we': 23,
#   'firm': 3,
#   'ground': 2,
#   'dealing': 1,
#   'events': 3,
#   'took': 21,
#   'leading': 5,
#   'part': 22,
#   'affairs': 23,
#   'decrees,': 1,
#   'records,': 1,
#   'dispatches': 1,
#   'guide': 2,
#   'us,': 1,
#   'writings.': 1,
#   'mere\r': 1,
#   'recapitulation': 1,
#   'few': 22,
#   'transactions': 2,
#   'statesmen': 2,
#   'soldiers': 27,
#   'fair': 2,
#   'indication': 1,
#   'activities,': 1,
#   'supplies': 1,
#   'sources': 1,
#   'drew': 7,
#   'experiences': 1,
#   'characters\r': 1,
#   'illustrate': 2,
#   'first': 50,
#   'mission': 4,
#   '1499': 2,
#   'Catherina': 2,
#   'Sforza,': 10,
#   '“my': 1,
#   'lady': 2,
#   'Forli”\r': 1,
#   'whose': 9,
#   'conduct': 8,
#   'fate': 1,
#   'moral': 3,
#   'it\r': 27,
#   'far': 11,
#   'earn': 2,
#   'confidence': 3,
#   'people': 68,
#   'rely': 12,
#   'on\r': 13,
#   'fortresses.': 2,
#   'very': 45,
#   'noticeable': 1,
#   'principle': 2,
#   'is\r': 27,
#   'urged': 4,
#   'him': 250,
#   'many': 81,
#   'ways': 9,
#   'matter': 8,
#   'vital': 1,
#   'importance': 4,
#   'princes.\r': 2,
#   '1500': 2,
#   'sent': 42,
#   'France': 17,
#   'obtain': 7,
#   'terms': 20,
#   'Louis': 13,
#   'XII': 3,
#   'for\r': 25,
#   'continuing': 1,
#   'war': 20,
#   'against': 86,
#   'Pisa:': 1,
#   'king': 11,
#   'who,': 37,
#   'conduct\r': 2,
#   'Italy,': 18,
#   'committed': 5,
#   'five': 12,
#   'capital': 1,
#   'errors': 2,
#   'statecraft\r': 1,
#   'summarized': 1,
#   'consequently': 1,
#   'He,': 2,
#   'also,\r': 1,
#   'made': 53,
#   'dissolution': 2,
#   'marriage': 2,
#   'condition': 2,
#   'support\r': 3,
#   'Pope': 21,
#   'Alexander': 25,
#   'VI;': 1,
#   'refer': 1,
#   'urge\r': 1,
#   'such': 88,
#   'promises': 3,
#   'kept': 26,
#   'written': 11,
#   'concerning': 12,
#   'faith': 6,
#   'largely': 1,
#   'occupied': 9,
#   'arising': 2,
#   'out\r': 6,
#   'ambitions': 4,
#   'VI': 2,
#   'Cesare': 14,
#   'Borgia,': 4,
#   'Duke': 25,
#   'Valentino,': 5,
#   'these': 83,
#   'characters': 3,
#   'fill': 1,
#   'large': 7,
#   'space': 3,
#   '_The\r': 5,
#   'Prince_.': 4,
#   'never': 64,
#   'hesitates': 1,
#   'cite': 2,
#   'actions': 18,
#   'duke\r': 2,
#   'benefit': 1,
#   'usurpers': 1,
#   'keep': 48,
#   'states': 21,
#   'they': 369,
#   'seized;': 1,
#   'can,': 3,
#   'indeed,': 1,
#   'find': 30,
#   'precepts': 2,
#   'offer': 6,
#   'pattern': 1,
#   'Borgia’s': 1,
#   'conduct,': 2,
#   'insomuch': 1,
#   'acclaimed\r': 1,
#   'critics': 1,
#   '“hero”': 1,
#   'Yet': 3,
#   'Prince_': 9,
#   'duke': 37,
#   'point': 6,
#   'fact': 5,
#   'type': 2,
#   'rises': 2,
#   'fortune': 31,
#   'others,': 23,
#   'them;': 22,
#   'takes': 6,
#   'every': 51,
#   'course': 15,
#   'that\r': 53,
#   'might': 34,
#   'expected': 4,
#   'prudent': 8,
#   'save\r': 1,
#   'him;': 16,
#   'prepared': 9,
#   'all': 165,
#   'eventualities': 1,
#   'happens;\r': 1,
#   'abilities': 5,
#   'fail': 9,
#   'carry': 5,
#   'through,': 1,
#   'exclaims\r': 1,
#   'fault,': 2,
#   'extraordinary': 6,
#   'unforeseen\r': 1,
#   'fatality.\r': 1,
#   'On': 14,
#   'death': 24,
#   'Pius': 1,
#   'III,': 1,
#   '1503,': 1,
#   'Rome': 14,
#   'watch': 3,
#   'election': 3,
#   'successor,': 2,
#   'saw': 15,
#   'Borgia\r': 2,
#   'cheated': 1,
#   'allowing': 2,
#   'choice': 3,
#   'College': 1,
#   'fall': 8,
#   'Giuliano\r': 1,
#   'delle': 4,
#   'Rovere': 1,
#   '(Julius': 1,
#   'II),': 1,
#   'cardinals': 3,
#   'most\r': 12,
#   'reason': 29,
#   'fear': 40,
#   'duke.': 4,
#   'commenting': 1,
#   'election,\r': 1,
#   'says': 2,
#   'thinks': 2,
#   'favours': 2,
#   'cause': 20,
#   'great': 71,
#   'personages': 2,
#   'forget': 6,
#   'injuries': 5,
#   'deceives': 1,
#   'himself.': 4,
#   'Julius': 13,
#   'did': 69,
#   'rest': 9,
#   'had\r': 27,
#   'ruined': 7,
#   'Cesare.\r': 1,
#   'It': 47,
#   'II': 4,
#   '1506,': 1,
#   'pontiff': 3,
#   'commencing': 1,
#   'enterprise': 4,
#   'Bologna;': 2,
#   'brought\r': 5,
#   'successful': 5,
#   'issue,': 1,
#   'adventures,': 1,
#   'owing\r': 1,
#   'chiefly': 4,
#   'impetuous': 2,
#   'character.': 2,
#   'reference': 1,
#   'Julius\r': 2,
#   'moralizes': 1,
#   'resemblance': 2,
#   'between': 18,
#   'Fortune': 9,
#   'women,': 1,
#   'concludes': 2,
#   'bold': 2,
#   'rather': 19,
#   'cautious': 3,
#   'man\r': 4,
#   'win': 9,
#   'hold': 45,
#   'them': 168,
#   'both.\r': 1,
#   'impossible': 10,
#   'follow': 18,
#   'here': 8,
#   'varying': 2,
#   'Italian\r': 3,
#   'states,': 7,
#   '1507': 1,
#   'controlled': 1,
#   'France,': 16,
#   'Spain,': 5,
#   'Germany,\r': 1,
#   'results': 1,
#   'lasted': 1,
#   'our': 33,
#   'day;': 2,
#   'concerned': 1,
#   'those\r': 9,
#   'events,': 2,
#   'actors': 1,
#   'them,': 68,
#   'impinge': 1,
#   'personality': 1,
#   'Machiavelli.': 1,
#   'several': 6,
#   'meetings': 1,
#   'estimate': 1,
#   'monarch’s': 1,
#   'character': 9,
#   'has\r': 12,
#   'already': 16,
#   'alluded': 1,
#   'to.': 1,
#   'painted': 1,
#   'Ferdinand': 5,
#   'Aragon': 2,
#   'as\r': 30,
#   'accomplished': 5,
#   'things': 38,
#   'cloak': 3,
#   'religion,': 2,
#   'but\r': 17,
#   'reality': 2,
#   'mercy,': 4,
#   'faith,': 4,
#   'humanity,': 4,
#   'integrity;': 1,
#   'who,\r': 1,
#   'allowed': 10,
#   'himself': 90,
#   'influenced': 2,
#   'motives,': 1,
#   'would': 152,
#   'ruined.': 4,
#   'Emperor': 5,
#   'Maximilian': 2,
#   'interesting': 3,
#   'men\r': 5,
#   'age,': 2,
#   'drawn': 5,
#   'hands;': 1,
#   'envoy': 2,
#   'court': 4,
#   '1507-8,': 1,
#   'reveals': 1,
#   'secret': 6,
#   'failures': 1,
#   'describes': 1,
#   'secretive': 2,
#   'man,\r': 2,
#   'force': 7,
#   'character—ignoring': 1,
#   'human': 5,
#   ...})

# %%
# print this in a pretty way
pd.DataFrame(res,columns=['File','Word Frequency'])
# Out:
#           File                                     Word Frequency
# 0   1232-0.txt  {'﻿The': 1, 'Project': 65, 'Gutenberg': 19, 'e...
# 1     45-0.txt  {'﻿The': 1, 'Project': 66, 'Gutenberg': 18, 'E...
# 2   6133-0.txt  {'﻿The': 1, 'Project': 64, 'Gutenberg': 18, 'E...
# 3   2814-0.txt  {'﻿The': 1, 'Project': 66, 'Gutenberg': 20, 'E...
# 4     46-0.txt  {'﻿The': 1, 'Project': 64, 'Gutenberg': 18, 'E...
# ..         ...                                                ...
# 70    84-0.txt  {'﻿Project': 1, 'Gutenberg's': 1, 'Frankenstei...
# 71   215-0.txt  {'﻿
# ': 1, 'The': 165, 'Project': 66, 'Gutenber...
# 72   147-0.txt  {'﻿': 1, 'This': 15, 'eBook': 5, 'is': 357, 'f...
# 73  4300-0.txt  {'﻿
# ': 1, 'The': 967, 'Project': 66, 'Gutenber...
# 74   521-0.txt  {'﻿The': 1, 'Project': 66, 'Gutenberg': 20, 'e...
#
# [75 rows x 2 columns]
