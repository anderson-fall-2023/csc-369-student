# %% [markdown]
# # Chapter 3 - Why isn’t distributed computing built into my favorite language?
#
# ## Language extensions for distributed computing
#
# Paul E. Anderson

# %% [markdown]
# ## Ice Breaker
#
# If you were stranded on a desert island, what two items do you bring with you?

# %% [markdown]
# While this text can be viewed as PDF, it is most useful to have a Jupyter environment. I have an environment ready for each of you, but you can get your own local environment going in several ways. One popular way is with Anaconda (<a href="https://www.anaconda.com/">https://www.anaconda.com/</a>. Because of the limited time, you can use my server.

# %%
# %load_ext autoreload
# %autoreload 2
    
import os
from pathlib import Path
home = str(Path.home())

import pandas as pd

# %% [markdown]
# ## Motivation: What about programming Languages?
# For the sake of the discussion, let's focus on imperative programming languages such as Python and Java. These programming languages provide a way to algorithmicly specify your program. We're comfortable and familiar with this paradigm. There are other approaches of course. Functional and logic programming for example. Most of our languages are designed for software engineers in mind. I'm oversimplying the world here, but our main programming languages are used to build software.

# %% [markdown]
# Consider the Python programming language: Python has multiprocessor libraries (https://docs.python.org/2/library/multiprocessing.html). So why isn't that good enough? Among other things, this library does not efficiently solve these common problems of distributed computing:
# * Running the same code on more than one machine.
# * Building microservices and actors that have state and can communicate.
# * Gracefully handling machine failures.
# * Efficiently handling large objects and numerical data.

# %% [markdown]
# There are languages such as Julia that are gaining popularity. These languages provide better support for **distributed computing at a lower level of abstraction** than we need in this course. Still there are arguments for their adoption. We will not unpack those arguments at the moment. We are building towards domain specific tools such as:
# * TensorFlow for neural network training
# * Spark for data processing and SQL
# * Flink for stream processing

# %% [markdown]
# These provide **higher level abstractions** for neural networks, datasets, and streams. One of the biggest hurtles for their adoption is that these often require rewriting a lot of our code and our thinking about how to compose solutions. This leads to an obvious question:

# %% [markdown]
# What about something in between? **Can't we just improve our favorite languages?**
#
# We will consider two popular distributed computing platforms for Python: Ray and Dask.

# %% [markdown]
# ## Python Library 1: Ray
# Ray is a Python library that attempts to translate the traditional ideas of functions and classes to distributed settings such as **tasks** and **actors**. We've already seen the idea of tasks with our GNU Parallel work. Ray is designed to take similar ideas and bring them into Python as easily as possible.

# %% [markdown]
# ### Starting Ray

# %%
import ray
ray.init()
# Out:
# 2023-10-10 01:43:09,547	INFO util.py:159 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2023-10-10 01:43:11,325	INFO worker.py:1642 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.10.12', ray_version='2.7.1', ray_commit='9f07c12615958c3af3760604f6dcacc4b3758a47', protocol_version=None)

# %% [markdown]
# If you were connecting to a cluster, then you would pass additional arguments with connection specifics.

# %% [markdown]
# init() does the following:
# * Starts a number of worker processes for executing Python calls in parallel (approximately one per core in our environment)
# * Starts a scheduler process for assigning tasks to workers
# * Starts a shared memory object store for sharing objects without making copies
# * An in-memory database for storing metadata needed to rerun tasks in the even of failure

# %% [markdown]
# A **task** is the unit of work schedule by Ray and corresponds to a function call.
#
# Ray workers are separate processes as opposed to threads

# %% [markdown]
# ### Simple parallel example
# All we need is a little decoration
#
# **Detour:** <a href="https://realpython.com/primer-on-python-decorators/">For more information on decorators in Python</a>

# %%
import time

# %%
@ray.remote
def f(x):
    time.sleep(1)
    return "hello "+str(x)

def g(x):
    time.sleep(5)
    return x

# %% [markdown]
# A common pattern when performing distributed computing is that we get a handle to the eventual output immediate. This is because we don't want our main program to stop and wait unless we explicitly need this to be the case. In most settings we are setting up the distributed computing, but we need to decide ourselves how to grab the data. In Ray, we get back futures (https://en.wikipedia.org/wiki/Futures_and_promises).

# %% [markdown]
# ### Start 4 tasks in parallel.

# %%
g(0)
# Out:
# 0

# %%
f.remote(0)
# Out:
# ObjectRef(f4402ec78d3a2607ffffffffffffffffffffffff0100000001000000)

# %%
result_ids = []
for i in range(4):
    result_ids.append(f.remote(i))
result_ids
# Out:
# [ObjectRef(2751d69548dba956ffffffffffffffffffffffff0100000001000000),
#  ObjectRef(71b133a11e1c461cffffffffffffffffffffffff0100000001000000),
#  ObjectRef(5d4b8d1788f12d2dffffffffffffffffffffffff0100000001000000),
#  ObjectRef(c54e76759b2a0c10ffffffffffffffffffffffff0100000001000000)]

# %% [markdown]
# ### Wait for the tasks to complete and retrieve the results.
# **With at least 4 cores, this will take 1 second.**

# %%
results = ray.get(result_ids)  # [0, 1, 2, 3]
results
# Out:
# ['hello 0', 'hello 1', 'hello 2', 'hello 3']

# %% [markdown]
# ### Class exercise
# Using Ray, create a simple parallel search for Prime numbers. Take 5-10 minutes to design and test your solution. We'll run each solution for 30 seconds to see who's solution finds the most prime numbers. Here is naive code to test for prime numbers:

# %%
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2,n):
        if n % i == 0:
            return False
    return True

# %%
is_prime(6),is_prime(7)
# Out:
# (False, True)

# %%
import signal

class TimeoutException(Exception):   # Custom exception class
    pass

def timeout_handler(signum, frame):   # Custom signal handler
    raise TimeoutException
    
# Your solution/code here!

# %%
result_ids = [find.remote(3)]
result_ids
# Out:
# [ObjectRef(1e360ffa862f8fe3ffffffffffffffffffffffff0100000001000000)]

# %%
import itertools
import numpy as np
all_results = set(itertools.chain(*ray.get(result_ids)))

# %%
max(all_results)
# Out:
# 22171

# %%
len(all_results)
# Out:
# 2486

# %%
result_ids = [find.remote(3),find.remote(19428)]
result_ids
# Out:
# [ObjectRef(18b2ad3c688fb947ffffffffffffffffffffffff0100000001000000),
#  ObjectRef(dc746dc61b2c1923ffffffffffffffffffffffff0100000001000000)]

# %%
import itertools
import numpy as np
all_results = set(itertools.chain(*ray.get(result_ids)))

# %%
max(all_results)
# Out:
# 30593

# %%
len(all_results)
# Out:
# 3301

# %% [markdown]
# ### Details (and order) make a big difference
# Consider the problem of adding a large set of integers together. If we structure our aggregation incorrectly, we don't see the benefits of our distributed environment.
# <img src="https://miro.medium.com/max/1400/1*vHz3troEmr4uLns0V8VmdA.jpeg">
# * Both executions result in the same, but the one on the right shows how to turn linear into logarithmic!

# %% [markdown]
# **Slow approach in action**

# %%
# %%timeit 
@ray.remote
def add(x, y):
    time.sleep(1)
    return x + y

values = [1, 2, 3, 4, 5, 6, 7, 8]
while len(values) > 1:
    #import pdb; pdb.set_trace()
    values = [add.remote(values[0], values[1])] + values[2:]
result = ray.get(values[0])
result
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 get_ipython().run_cell_magic('timeit', '', '@ray.remote\ndef add(x, y):\n    time.sleep(1)\n    return x + y\n\nvalues = [1, 2, 3, 4, 5, 6, 7, 8]\nwhile len(values) > 1:\n    #import pdb; pdb.set_trace()\n    values = [add.remote(values[0], values[1])] + values[2:]\nresult = ray.get(values[0])\nresult\n')
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/magics/execution.py:1189, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1186         if time_number >= 0.2:
#    1187             break
# -> 1189 all_runs = timer.repeat(repeat, number)
#    1190 best = min(all_runs) / number
#    1191 worst = max(all_runs) / number
#
# File /usr/lib/python3.10/timeit.py:206, in Timer.repeat(self, repeat, number)
#     204 r = []
#     205 for i in range(repeat):
# --> 206     t = self.timeit(number)
#     207     r.append(t)
#     208 return r
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/magics/execution.py:173, in Timer.timeit(self, number)
#     171 gc.disable()
#     172 try:
# --> 173     timing = self.inner(it, self.timer)
#     174 finally:
#     175     if gcold:
#
# File <magic-timeit>:10, in inner(_it, _timer)
#
# File /usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py:24, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      21 @wraps(fn)
#      22 def auto_init_wrapper(*args, **kwargs):
#      23     auto_init_ray()
# ---> 24     return fn(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/ray/_private/worker.py:2541, in get(object_refs, timeout)
#    2536     raise ValueError(
#    2537         "'object_refs' must either be an ObjectRef or a list of ObjectRefs."
#    2538     )
#    2540 # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 2541 values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    2542 for i, value in enumerate(values):
#    2543     if isinstance(value, RayError):
#
# File /usr/local/lib/python3.10/dist-packages/ray/_private/worker.py:756, in Worker.get_objects(self, object_refs, timeout)
#     750         raise TypeError(
#     751             f"Attempting to call `get` on the value {object_ref}, "
#     752             "which is not an ray.ObjectRef."
#     753         )
#     755 timeout_ms = int(timeout * 1000) if timeout is not None else -1
# --> 756 data_metadata_pairs = self.core_worker.get_objects(
#     757     object_refs, self.current_task_id, timeout_ms
#     758 )
#     759 debugger_breakpoint = b""
#     760 for data, metadata in data_metadata_pairs:
#
# File python/ray/_raylet.pyx:3110, in ray._raylet.CoreWorker.get_objects()
#
# File python/ray/_raylet.pyx:445, in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %% [markdown]
# **STOP and THINK:** This code produces the execution on the left (figure above). How would you change it to work like the execution on the right?

# %% [markdown]
# **Fast approach in action**

# %%
# %%timeit
values = [1, 2, 3, 4, 5, 6, 7, 8]
while len(values) > 1:
    values = values[2:] + [add.remote(values[0], values[1])] # remove 2 and put at end
result = ray.get(values[0])
result

# %% [markdown]
# ## Python Library 2: Dask (and Pandas)

# %% [markdown]
# One of the most widely used structured data processing tools available is a library in Python known as Pandas. We won't cover all of Pandas or Dask in this chapter. We will cover some very common use cases of the two. Hopefully, enough to know **when Pandas+Dask might be appropriate for your problem.**

# %% [markdown]
# ### Pandas in 10 minutes
# There are many resources out there for this purpose. I am being inspired by: https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html

# %%
import pandas as pd

# %% [markdown]
# **pd.Series**
# * a list with more power
# * elements have an integer 0-based index and a named index
# * a series has a name

# %%
s1 = pd.Series(["A","B","C",3.14],index=["i","ii","iii","iv"],name="first_example")
s1
# Out:
# i         A
# ii        B
# iii       C
# iv     3.14
# Name: first_example, dtype: object

# %% [markdown]
# **You can access in either a 0-based index way (iloc) or a named index manner (loc)**

# %%
s1.loc["ii"],s1.iloc[1]
# Out:
# ('B', 'B')

# %% [markdown]
# But a lot of other things still work as expected

# %%
len(s1),s1.shape
# Out:
# (4, (4,))

# %% [markdown]
# So the main concept (at this moment) is that Pandas provides extended functionality for common things such as lists and dictionaries. We'll see this in more detail as we examine **pd.DataFrame** by loading COVID19 data.

# %% [markdown]
# > The data set contains daily reports of Covid-19 cases and deaths in countries worldwide. The data also shows the country’s population and the number of cases per 100,000 people on a rolling 14 day average.
#
# https://corgis-edu.github.io/corgis/python/covid/

# %%
import sys
sys.path.insert(0,f'{home}/csc-369-student/data/covid')
import covid

# %% [markdown]
# **Let's see how it looks**

# %%
report = covid.get_report()
report
# Out:
# [{'Date': {'Day': 5, 'Month': 11, 'Year': 2020},
#   'Data': {'Cases': 121,
#    'Deaths': 6,
#    'Population': 38041757,
#    'Rate': 3.74588377},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 4, 'Month': 11, 'Year': 2020},
#   'Data': {'Cases': 86,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 3.78268543},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 3, 'Month': 11, 'Year': 2020},
#   'Data': {'Cases': 95,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 3.78794281},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 2, 'Month': 11, 'Year': 2020},
#   'Data': {'Cases': 132,
#    'Deaths': 5,
#    'Population': 38041757,
#    'Rate': 3.76691329},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 1, 'Month': 11, 'Year': 2020},
#   'Data': {'Cases': 76,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 3.57501889},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 31, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 157,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 3.55398937},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 30, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 123,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 3.26483343},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 29, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 0,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 2.94150452},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 28, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 113,
#    'Deaths': 7,
#    'Population': 38041757,
#    'Rate': 3.02562261},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 27, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 199,
#    'Deaths': 8,
#    'Population': 38041757,
#    'Rate': 2.90207416},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 26, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 65,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 2.71806583},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 25, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 81,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 2.79955524},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 24, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 61,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 2.58663132},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 23, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 116,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 2.45256811},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 22, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 135,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 2.35004918},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 21, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 88,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 2.17392693},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 20, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 87,
#    'Deaths': 5,
#    'Population': 38041757,
#    'Rate': 2.10558098},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 19, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 59,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 2.25804502},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 18, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 68,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 2.21861467},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 17, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 47,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 2.05826455},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 16, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 0,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.94785956},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 15, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 32,
#    'Deaths': 1,
#    'Population': 38041757,
#    'Rate': 1.99254729},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 14, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 66,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.94523087},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 13, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 129,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 1.81116766},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 12, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 96,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 1.50361089},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 11, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 0,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.25125661},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 10, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 10,
#    'Deaths': 1,
#    'Population': 38041757,
#    'Rate': 1.34326078},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 9, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 77,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 1.33274601},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 8, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 68,
#    'Deaths': 1,
#    'Population': 38041757,
#    'Rate': 1.1723959},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 7, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 62,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 1.05936222},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 6, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 145,
#    'Deaths': 5,
#    'Population': 38041757,
#    'Rate': 1.08302043},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 5, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 44,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 0.78072104},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 4, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 7,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 0.66505866},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 3, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 5,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 0.97524412},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 2, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 17,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.08564912},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 1, 'Month': 10, 'Year': 2020},
#   'Data': {'Cases': 14,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.04096138},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 30, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 15,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 1.04884745},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 29, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 12,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 1.11456471},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 28, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 0,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.34326078},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 27, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 35,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.54041255},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 26, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 6,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 1.54041255},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 25, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 16,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.61401588},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 24, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 25,
#    'Deaths': 5,
#    'Population': 38041757,
#    'Rate': 1.64556017},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 23, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 71,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 1.64293148},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 22, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 30,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 1.52464041},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 21, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 0,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.69813397},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 20, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 125,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 1.89265706},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 19, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 47,
#    'Deaths': 1,
#    'Population': 38041757,
#    'Rate': 1.61664457},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 18, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 0,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.53515517},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 17, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 17,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.65344624},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 16, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 40,
#    'Deaths': 10,
#    'Population': 38041757,
#    'Rate': 1.70864874},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 15, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 99,
#    'Deaths': 6,
#    'Population': 38041757,
#    'Rate': 1.62715933},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 14, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 75,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.45629446},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 13, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 35,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.3090878},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 12, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 34,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.22496971},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 11, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 28,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.16450983},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 10, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 24,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 1.09879257},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 9, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 26,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 1.18028197},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 8, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 96,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 1.11456471},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 7, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 74,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 1.04884745},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 6, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 20,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 0.85432437},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 5, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 16,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.07776305},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 4, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 45,
#    'Deaths': 1,
#    'Population': 38041757,
#    'Rate': 1.13559424},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 3, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 38,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 1.27228614},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 2, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 9,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.59298636},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 1, 'Month': 9, 'Year': 2020},
#   'Data': {'Cases': 34,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 1.56932815},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 31, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 19,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.48783875},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 30, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 3,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.55618469},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 29, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 11,
#    'Deaths': 1,
#    'Population': 38041757,
#    'Rate': 1.86374147},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 28, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 3,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.85322671},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 27, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 55,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 2.05300717},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 26, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 1,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 2.10820967},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 25, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 71,
#    'Deaths': 10,
#    'Population': 38041757,
#    'Rate': 2.67074941},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 24, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 2.48411239},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 23, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 105,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 2.48411239},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 22, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 38,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 2.31061883},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 21, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 97,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 2.41576644},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 20, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 160,
#    'Deaths': 8,
#    'Population': 38041757,
#    'Rate': 2.26855978},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 19, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 2.02409158},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 18, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 3,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 2.23964419},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 17, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 45,
#    'Deaths': 5,
#    'Population': 38041757,
#    'Rate': 2.32901966},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 16, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 120,
#    'Deaths': 7,
#    'Population': 38041757,
#    'Rate': 2.21072859},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 15, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 7,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.89528575},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 14, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 79,
#    'Deaths': 9,
#    'Population': 38041757,
#    'Rate': 2.3185049},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 13, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 76,
#    'Deaths': 10,
#    'Population': 38041757,
#    'Rate': 2.29747538},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 12, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 215,
#    'Deaths': 32,
#    'Population': 38041757,
#    'Rate': 2.09769491},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 11, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.80328159},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 10, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 2.07929408},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 9, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 39,
#    'Deaths': 5,
#    'Population': 38041757,
#    'Rate': 2.35793526},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 8, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 78,
#    'Deaths': 9,
#    'Population': 38041757,
#    'Rate': 2.57348786},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 7, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 41,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 2.65234858},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 6, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 67,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 2.57874525},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 5, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 82,
#    'Deaths': 6,
#    'Population': 38041757,
#    'Rate': 2.89681678},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 4, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 37,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 2.97567749},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 3, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 1, 'Population': 38041757, 'Rate': 3.2464326},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 2, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 3.70382472},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 1, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 168,
#    'Deaths': 12,
#    'Population': 38041757,
#    'Rate': 3.73536901},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 31, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 71,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 3.86943221},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 30, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 3.88257567},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 29, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 103,
#    'Deaths': 1,
#    'Population': 38041757,
#    'Rate': 4.55026302},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 28, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 105,
#    'Deaths': 1,
#    'Population': 38041757,
#    'Rate': 5.02868466},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 27, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 106,
#    'Deaths': 10,
#    'Population': 38041757,
#    'Rate': 4.76318694},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 26, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 121,
#    'Deaths': 13,
#    'Population': 38041757,
#    'Rate': 4.48454576},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 25, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 108,
#    'Deaths': 35,
#    'Population': 38041757,
#    'Rate': 4.38991291},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 24, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 13,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 5.30995453},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 23, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 188,
#    'Deaths': 21,
#    'Population': 38041757,
#    'Rate': 5.9460976},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 22, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 112,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 5.60699654},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 21, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 140,
#    'Deaths': 5,
#    'Population': 38041757,
#    'Rate': 5.8646082},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 20, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 174,
#    'Deaths': 17,
#    'Population': 38041757,
#    'Rate': 6.63481448},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 19, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 12,
#    'Deaths': 17,
#    'Population': 38041757,
#    'Rate': 6.91082696},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 18, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 219,
#    'Deaths': 32,
#    'Population': 38041757,
#    'Rate': 7.79406692},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 17, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 76,
#    'Deaths': 21,
#    'Population': 38041757,
#    'Rate': 8.01224823},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 16, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 254,
#    'Deaths': 49,
#    'Population': 38041757,
#    'Rate': 8.30140416},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 15, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 285,
#    'Deaths': 33,
#    'Population': 38041757,
#    'Rate': 8.47226904},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 14, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 4, 'Deaths': 2, 'Population': 38041757, 'Rate': 8.4564969},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 13, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 9.15835722},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 12, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 85,
#    'Deaths': 16,
#    'Population': 38041757,
#    'Rate': 10.08102754},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 11, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 458,
#    'Deaths': 37,
#    'Population': 38041757,
#    'Rate': 10.29132277},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 10, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 255,
#    'Deaths': 20,
#    'Population': 38041757,
#    'Rate': 9.81290112},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 9, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 59,
#    'Deaths': 1,
#    'Population': 38041757,
#    'Rate': 10.35178265},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 8, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 210,
#    'Deaths': 16,
#    'Population': 38041757,
#    'Rate': 10.81180346},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 7, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 433,
#    'Deaths': 56,
#    'Population': 38041757,
#    'Rate': 11.14827583},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 6, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 279,
#    'Deaths': 38,
#    'Population': 38041757,
#    'Rate': 10.82494691},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 5, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 348,
#    'Deaths': 7,
#    'Population': 38041757,
#    'Rate': 11.16667666},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 4, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 302,
#    'Deaths': 12,
#    'Population': 38041757,
#    'Rate': 11.68715735},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 3, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 186,
#    'Deaths': 33,
#    'Population': 38041757,
#    'Rate': 11.80281973},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 2, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 319,
#    'Deaths': 28,
#    'Population': 38041757,
#    'Rate': 13.04356158},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 1, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 279,
#    'Deaths': 13,
#    'Population': 38041757,
#    'Rate': 13.68759072},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 30, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 271,
#    'Deaths': 12,
#    'Population': 38041757,
#    'Rate': 15.01245066},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 29, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 351,
#    'Deaths': 18,
#    'Population': 38041757,
#    'Rate': 16.30050894},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 28, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 165,
#    'Deaths': 20,
#    'Population': 38041757,
#    'Rate': 17.12328902},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 27, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 276,
#    'Deaths': 8,
#    'Population': 38041757,
#    'Rate': 18.15110695},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 26, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 460,
#    'Deaths': 36,
#    'Population': 38041757,
#    'Rate': 19.15000929},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 25, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 234,
#    'Deaths': 21,
#    'Population': 38041757,
#    'Rate': 19.90444343},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 24, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 338,
#    'Deaths': 20,
#    'Population': 38041757,
#    'Rate': 21.08735409},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 23, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 310,
#    'Deaths': 17,
#    'Population': 38041757,
#    'Rate': 21.62360692},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 22, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 409,
#    'Deaths': 12,
#    'Population': 38041757,
#    'Rate': 22.32020987},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 21, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 546,
#    'Deaths': 21,
#    'Population': 38041757,
#    'Rate': 23.32436959},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 20, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 346,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 23.41900244},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 19, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 658,
#    'Deaths': 42,
#    'Population': 38041757,
#    'Rate': 24.91472726},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 18, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 564,
#    'Deaths': 13,
#    'Population': 38041757,
#    'Rate': 25.25382831},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 17, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 783,
#    'Deaths': 13,
#    'Population': 38041757,
#    'Rate': 25.76379424},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 16, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 761,
#    'Deaths': 7,
#    'Population': 38041757,
#    'Rate': 25.70070567},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 15, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 664,
#    'Deaths': 20,
#    'Population': 38041757,
#    'Rate': 25.13290856},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 14, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 556,
#    'Deaths': 5,
#    'Population': 38041757,
#    'Rate': 25.1749676},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 13, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 656,
#    'Deaths': 20,
#    'Population': 38041757,
#    'Rate': 25.98986161},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 12, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 747,
#    'Deaths': 21,
#    'Population': 38041757,
#    'Rate': 25.90311483},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 11, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 684,
#    'Deaths': 21,
#    'Population': 38041757,
#    'Rate': 25.46412354},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 10, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 542,
#    'Deaths': 15,
#    'Population': 38041757,
#    'Rate': 25.30903081},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 9, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 575,
#    'Deaths': 12,
#    'Population': 38041757,
#    'Rate': 25.61395889},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 8, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 791,
#    'Deaths': 30,
#    'Population': 38041757,
#    'Rate': 25.65601794},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 7, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 582,
#    'Deaths': 18,
#    'Population': 38041757,
#    'Rate': 25.11187903},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 6, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 915,
#    'Deaths': 9,
#    'Population': 38041757,
#    'Rate': 25.63761711},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 5, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 787,
#    'Deaths': 6,
#    'Population': 38041757,
#    'Rate': 24.65185822},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 4, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 758,
#    'Deaths': 24,
#    'Population': 38041757,
#    'Rate': 23.97891349},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 3, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 759,
#    'Deaths': 5,
#    'Population': 38041757,
#    'Rate': 23.27968185},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 2, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 545,
#    'Deaths': 8,
#    'Population': 38041757,
#    'Rate': 22.81177497},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 1, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 680,
#    'Deaths': 8,
#    'Population': 38041757,
#    'Rate': 22.45164439},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 31, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 866,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 21.35285181},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 30, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 623,
#    'Deaths': 11,
#    'Population': 38041757,
#    'Rate': 19.07640596},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 29, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 580,
#    'Deaths': 8,
#    'Population': 38041757,
#    'Rate': 20.23302972},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 28, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 625,
#    'Deaths': 7,
#    'Population': 38041757,
#    'Rate': 19.00543132},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 27, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 658,
#    'Deaths': 1,
#    'Population': 38041757,
#    'Rate': 18.04333065},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 26, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 591,
#    'Deaths': 1,
#    'Population': 38041757,
#    'Rate': 17.04968569},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 25, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 584,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 16.24530644},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 24, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 782,
#    'Deaths': 11,
#    'Population': 38041757,
#    'Rate': 15.68013801},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 23, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 540,
#    'Deaths': 12,
#    'Population': 38041757,
#    'Rate': 14.29481819},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 22, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 531,
#    'Deaths': 6,
#    'Population': 38041757,
#    'Rate': 13.44049382},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 21, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 492,
#    'Deaths': 9,
#    'Population': 38041757,
#    'Rate': 12.49416529},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 20, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 581,
#    'Deaths': 5,
#    'Population': 38041757,
#    'Rate': 11.64246962},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 19, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 408,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 10.98266833},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 18, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 262,
#    'Deaths': 1,
#    'Population': 38041757,
#    'Rate': 10.40961384},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 17, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 0,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 10.3386392},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 16, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 1063,
#    'Deaths': 32,
#    'Population': 38041757,
#    'Rate': 10.6908837},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 15, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 113,
#    'Deaths': 6,
#    'Population': 38041757,
#    'Rate': 8.32769107},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 14, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 259,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 8.61421832},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 13, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 280,
#    'Deaths': 5,
#    'Population': 38041757,
#    'Rate': 8.25408774},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 12, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 285,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 7.84401204},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 11, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 369,
#    'Deaths': 5,
#    'Population': 38041757,
#    'Rate': 7.54697003},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 10, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 255,
#    'Deaths': 6,
#    'Population': 38041757,
#    'Rate': 6.75573423},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 9, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 215,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 6.37983151},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 8, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 171,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 5.99867141},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 7, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 168,
#    'Deaths': 9,
#    'Population': 38041757,
#    'Rate': 5.82517784},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 6, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 330,
#    'Deaths': 5,
#    'Population': 38041757,
#    'Rate': 5.60436785},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 5, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 190,
#    'Deaths': 5,
#    'Population': 38041757,
#    'Rate': 4.89725015},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 4, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 235,
#    'Deaths': 13,
#    'Population': 38041757,
#    'Rate': 4.48980314},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 3, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 134,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 4.10338566},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 2, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 164,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 3.91674864},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 1, 'Month': 5, 'Year': 2020},
#   'Data': {'Cases': 222,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 3.61970663},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 30, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 122,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 3.06242427},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 29, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 124,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 2.92573237},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 28, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 172,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 2.7285806},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 27, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 68,
#    'Deaths': 10,
#    'Population': 38041757,
#    'Rate': 2.42890989},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 26, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 112,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 2.38685085},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 25, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 70, 'Deaths': 1, 'Population': 38041757, 'Rate': 2.181813},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 24, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 105,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 2.09506622},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 23, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 84,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 1.97940384},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 22, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 61,
#    'Deaths': 1,
#    'Population': 38041757,
#    'Rate': 1.90580051},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 21, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 35,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 1.82431111},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 20, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 88,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 1.83219718},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 19, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 63,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.67710445},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 18, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 51,
#    'Deaths': 1,
#    'Population': 38041757,
#    'Rate': 1.60350112},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 17, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 10,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 1.46943791},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 16, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 70,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 1.55618469},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 15, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 49,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 1.44052232},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 14, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 58,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 1.37743375},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 13, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 52,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.29594435},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 12, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 34,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 1.18028197},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 11, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 37,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 1.13033686},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 10, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 61,
#    'Deaths': 1,
#    'Population': 38041757,
#    'Rate': 1.07513436},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 9, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 56,
#    'Deaths': 3,
#    'Population': 38041757,
#    'Rate': 0.91478425},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 8, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 30,
#    'Deaths': 4,
#    'Population': 38041757,
#    'Rate': 0.85432437},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 7, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 38,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 0.78072104},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 6, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 29,
#    'Deaths': 2,
#    'Population': 38041757,
#    'Rate': 0.69660295},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 5, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 35,
#    'Deaths': 1,
#    'Population': 38041757,
#    'Rate': 0.64665783},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 4, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 0,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 0.55465367},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 3, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 43,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 0.55991105},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 2, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 26,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 0.44687736},
#   'Location': {'Country': 'Afghanistan', 'Code': 'AFG', 'Continent': 'Asia'}},
#  {'Date': {'Day': 1, 'Month': 4, 'Year': 2020},
#   'Data': {'Cases': 25,
#    'Deaths': 0,
#    'Population': 38041757,
#    'Rate': 0.37853141},
# ...
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 24, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 116.8331649},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 23, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 116.8331649},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 22, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 21, 'Deaths': 0, 'Population': 76177, 'Rate': 118.1458971},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 21, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 105.0185752},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 20, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 19, 'Deaths': 0, 'Population': 76177, 'Rate': 111.5822361},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 19, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 86.64032451},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 18, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 16, 'Deaths': 0, 'Population': 76177, 'Rate': 89.26578889},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 17, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 84.01486013},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 16, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 84.01486013},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 15, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 8, 'Deaths': 0, 'Population': 76177, 'Rate': 84.01486013},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 14, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 4, 'Deaths': 0, 'Population': 76177, 'Rate': 77.45119918},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 13, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 14, 'Deaths': 1, 'Population': 76177, 'Rate': 77.45119918},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 12, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 73.51300261},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 11, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 7, 'Deaths': 0, 'Population': 76177, 'Rate': 73.51300261},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 10, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 77.45119918},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 9, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 1, 'Deaths': 0, 'Population': 76177, 'Rate': 77.45119918},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 8, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 11, 'Deaths': 0, 'Population': 76177, 'Rate': 86.64032451},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 7, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 5, 'Deaths': 0, 'Population': 76177, 'Rate': 72.20027042},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 6, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 65.63660948},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 5, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 2, 'Deaths': 0, 'Population': 76177, 'Rate': 72.20027042},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 4, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 12, 'Deaths': 0, 'Population': 76177, 'Rate': 69.57480604},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 3, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 59.07294853},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 2, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 59.07294853},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 1, 'Month': 8, 'Year': 2020},
#   'Data': {'Cases': 3, 'Deaths': 0, 'Population': 76177, 'Rate': 59.07294853},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 31, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 4, 'Deaths': 0, 'Population': 76177, 'Rate': 59.07294853},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 30, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 11, 'Deaths': 0, 'Population': 76177, 'Rate': 73.51300261},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 29, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 60.38568072},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 28, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 10, 'Deaths': 0, 'Population': 76177, 'Rate': 64.32387729},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 27, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 55.13475196},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 26, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 8, 'Deaths': 0, 'Population': 76177, 'Rate': 55.13475196},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 25, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 44.63289444},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 24, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 44.63289444},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 23, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 5, 'Deaths': 0, 'Population': 76177, 'Rate': 44.63289444},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 22, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 38.0692335},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 21, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 4, 'Deaths': 0, 'Population': 76177, 'Rate': 38.0692335},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 20, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 32.81830474},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 19, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 32.81830474},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 18, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 3, 'Deaths': 0, 'Population': 76177, 'Rate': 32.81830474},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 17, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 15, 'Deaths': 0, 'Population': 76177, 'Rate': 28.88010817},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 16, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 1, 'Deaths': 0, 'Population': 76177, 'Rate': 9.18912533},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 15, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 3, 'Deaths': 0, 'Population': 76177, 'Rate': 7.87639314},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 14, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 3, 'Deaths': 0, 'Population': 76177, 'Rate': 3.93819657},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 13, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 0.0},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 12, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 0.0},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 11, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 0.0},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 10, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 0.0},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 9, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 0.0},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 8, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 0.0},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 7, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 0.0},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 6, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 0.0},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 5, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 0.0},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 4, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 0.0},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 3, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 0.0},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 2, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 1.31273219},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 1, 'Month': 7, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 1.31273219},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 30, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 2.62546438},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 29, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 2.62546438},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 28, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 2.62546438},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 27, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 2.62546438},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 26, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 3.93819657},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 25, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 3.93819657},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 24, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 3.93819657},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 23, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 3.93819657},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 22, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 3.93819657},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 21, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 3.93819657},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 20, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 3.93819657},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 19, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 1, 'Deaths': 0, 'Population': 76177, 'Rate': 3.93819657},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 18, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 3.93819657},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 17, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 1, 'Deaths': 1, 'Population': 76177, 'Rate': 13.1273219},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 16, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 115.5204327},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 15, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 116.8331649},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 14, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 116.8331649},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 13, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 1, 'Deaths': 0, 'Population': 76177, 'Rate': 116.8331649},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 12, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 116.8331649},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 11, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 116.8331649},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 10, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 116.8331649},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 9, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 116.8331649},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  {'Date': {'Day': 8, 'Month': 6, 'Year': 2020},
#   'Data': {'Cases': 0, 'Deaths': 0, 'Population': 76177, 'Rate': 116.8331649},
#   'Location': {'Country': 'Andorra', 'Code': 'AND', 'Continent': 'Europe'}},
#  ...]

# %% [markdown]
# That's not great. It's a dictionary that is very machine readable, but not very useful for us to easily ask questions about. Let's throw it into a DataFrame and see what happens.

# %%
report_df = pd.DataFrame(report)
report_df
# Out:
#                                         Date  \
# 0      {'Day': 5, 'Month': 11, 'Year': 2020}
# 1      {'Day': 4, 'Month': 11, 'Year': 2020}
# 2      {'Day': 3, 'Month': 11, 'Year': 2020}
# 3      {'Day': 2, 'Month': 11, 'Year': 2020}
# 4      {'Day': 1, 'Month': 11, 'Year': 2020}
# ...                                      ...
# 53585  {'Day': 25, 'Month': 3, 'Year': 2020}
# 53586  {'Day': 24, 'Month': 3, 'Year': 2020}
# 53587  {'Day': 23, 'Month': 3, 'Year': 2020}
# 53588  {'Day': 22, 'Month': 3, 'Year': 2020}
# 53589  {'Day': 21, 'Month': 3, 'Year': 2020}
#
#                                                     Data  \
# 0      {'Cases': 121, 'Deaths': 6, 'Population': 3804...
# 1      {'Cases': 86, 'Deaths': 4, 'Population': 38041...
# 2      {'Cases': 95, 'Deaths': 3, 'Population': 38041...
# 3      {'Cases': 132, 'Deaths': 5, 'Population': 3804...
# 4      {'Cases': 76, 'Deaths': 0, 'Population': 38041...
# ...                                                  ...
# 53585  {'Cases': 0, 'Deaths': 0, 'Population': 146454...
# 53586  {'Cases': 0, 'Deaths': 1, 'Population': 146454...
# 53587  {'Cases': 0, 'Deaths': 0, 'Population': 146454...
# 53588  {'Cases': 1, 'Deaths': 0, 'Population': 146454...
# 53589  {'Cases': 1, 'Deaths': 0, 'Population': 146454...
#
#                                                 Location
# 0      {'Country': 'Afghanistan', 'Code': 'AFG', 'Con...
# 1      {'Country': 'Afghanistan', 'Code': 'AFG', 'Con...
# 2      {'Country': 'Afghanistan', 'Code': 'AFG', 'Con...
# 3      {'Country': 'Afghanistan', 'Code': 'AFG', 'Con...
# 4      {'Country': 'Afghanistan', 'Code': 'AFG', 'Con...
# ...                                                  ...
# 53585  {'Country': 'Zimbabwe', 'Code': 'ZWE', 'Contin...
# 53586  {'Country': 'Zimbabwe', 'Code': 'ZWE', 'Contin...
# 53587  {'Country': 'Zimbabwe', 'Code': 'ZWE', 'Contin...
# 53588  {'Country': 'Zimbabwe', 'Code': 'ZWE', 'Contin...
# 53589  {'Country': 'Zimbabwe', 'Code': 'ZWE', 'Contin...
#
# [53590 rows x 3 columns]

# %% [markdown]
# That is not bad, but there are still dictionaries inside each cell of this DataFrame.
# * A DataFrame is a table-like data structure.
# * A DataFrame has column names (e.g., report_df.columns) and can be indexed using iloc or loc.
# * You can also access columns by name (e.g., report_df['Date'])
# Let's try to process one of those columns.

# %%
report_df['Date'] # By name
# Out:
# 0        {'Day': 5, 'Month': 11, 'Year': 2020}
# 1        {'Day': 4, 'Month': 11, 'Year': 2020}
# 2        {'Day': 3, 'Month': 11, 'Year': 2020}
# 3        {'Day': 2, 'Month': 11, 'Year': 2020}
# 4        {'Day': 1, 'Month': 11, 'Year': 2020}
#                          ...
# 53585    {'Day': 25, 'Month': 3, 'Year': 2020}
# 53586    {'Day': 24, 'Month': 3, 'Year': 2020}
# 53587    {'Day': 23, 'Month': 3, 'Year': 2020}
# 53588    {'Day': 22, 'Month': 3, 'Year': 2020}
# 53589    {'Day': 21, 'Month': 3, 'Year': 2020}
# Name: Date, Length: 53590, dtype: object

# %%
type(report_df['Date'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# So now we can say a DataFrame is made up of a collection of pd.Series objects

# %% [markdown]
# Because each column is a Series that is made up of individual dictionaries, let's throw each column into a DataFrame and see what happens. Notice that I cast this to a generic List object.

# %%
date_df = pd.DataFrame(list(report_df['Date']))
date_df
# Out:
#        Day  Month  Year
# 0        5     11  2020
# 1        4     11  2020
# 2        3     11  2020
# 3        2     11  2020
# 4        1     11  2020
# ...    ...    ...   ...
# 53585   25      3  2020
# 53586   24      3  2020
# 53587   23      3  2020
# 53588   22      3  2020
# 53589   21      3  2020
#
# [53590 rows x 3 columns]

# %% [markdown]
# This looks much better. We can now see clear what data we have. (Trust me. We are getting to distributed computing). But let's process the ``data`` and ``location``.

# %%
data_df = pd.DataFrame(list(report_df['Data']))
location_df = pd.DataFrame(list(report_df['Location']))
data_df
# Out:
#        Cases  Deaths  Population      Rate
# 0        121       6    38041757  3.745884
# 1         86       4    38041757  3.782685
# 2         95       3    38041757  3.787943
# 3        132       5    38041757  3.766913
# 4         76       0    38041757  3.575019
# ...      ...     ...         ...       ...
# 53585      0       0    14645473  0.000000
# 53586      0       1    14645473  0.000000
# 53587      0       0    14645473  0.000000
# 53588      1       0    14645473  0.000000
# 53589      1       0    14645473  0.000000
#
# [53590 rows x 4 columns]

# %%
location_df
# Out:
#            Country Code Continent
# 0      Afghanistan  AFG      Asia
# 1      Afghanistan  AFG      Asia
# 2      Afghanistan  AFG      Asia
# 3      Afghanistan  AFG      Asia
# 4      Afghanistan  AFG      Asia
# ...            ...  ...       ...
# 53585     Zimbabwe  ZWE    Africa
# 53586     Zimbabwe  ZWE    Africa
# 53587     Zimbabwe  ZWE    Africa
# 53588     Zimbabwe  ZWE    Africa
# 53589     Zimbabwe  ZWE    Africa
#
# [53590 rows x 3 columns]

# %% [markdown]
# Finally, we can join all of this together:

# %%
report_df2 = date_df.join(data_df).join(location_df)
report_df2
# Out:
#        Day  Month  Year  Cases  Deaths  Population      Rate      Country  \
# 0        5     11  2020    121       6    38041757  3.745884  Afghanistan
# 1        4     11  2020     86       4    38041757  3.782685  Afghanistan
# 2        3     11  2020     95       3    38041757  3.787943  Afghanistan
# 3        2     11  2020    132       5    38041757  3.766913  Afghanistan
# 4        1     11  2020     76       0    38041757  3.575019  Afghanistan
# ...    ...    ...   ...    ...     ...         ...       ...          ...
# 53585   25      3  2020      0       0    14645473  0.000000     Zimbabwe
# 53586   24      3  2020      0       1    14645473  0.000000     Zimbabwe
# 53587   23      3  2020      0       0    14645473  0.000000     Zimbabwe
# 53588   22      3  2020      1       0    14645473  0.000000     Zimbabwe
# 53589   21      3  2020      1       0    14645473  0.000000     Zimbabwe
#
#       Code Continent
# 0      AFG      Asia
# 1      AFG      Asia
# 2      AFG      Asia
# 3      AFG      Asia
# 4      AFG      Asia
# ...    ...       ...
# 53585  ZWE    Africa
# 53586  ZWE    Africa
# 53587  ZWE    Africa
# 53588  ZWE    Africa
# 53589  ZWE    Africa
#
# [53590 rows x 10 columns]

# %% [markdown]
# There is a lot more to show about Pandas and related data science tools, but let's consider the following:
# * This sample dataset has 50,000+ rows.
# * How large could this dataset be if we approached collecting all of the data in the world?
# * Could that fit into your computer's memory?
# * Even if it could fit into your computer's memory, processing it with pure Python would only make use of a single core unless you did some major coding to use the multiprocessing.
#
# **And here comes the Dask library**

# %% [markdown]
# ### Dask DataFrame
# * Implements a blocked parallel DataFrame object that mimics a large subset of the Pandas DataFrame API.
# * One Dask DataFrame is comprised of many in-memory pandas DataFrames separated along the index.
# * One operation on a Dask DataFrame triggers many pandas operations on the constituent pandas DataFrames
# * This is done to exploit potential parallelism and memory constraints

# %%
from dask import dataframe as dd 
report_dd2 = dd.from_pandas(report_df2,npartitions=3)
report_dd2
# Out:
# Dask DataFrame Structure:
#                  Day  Month   Year  Cases Deaths Population     Rate Country    Code Continent
# npartitions=3
# 0              int64  int64  int64  int64  int64      int64  float64  object  object    object
# 17864            ...    ...    ...    ...    ...        ...      ...     ...     ...       ...
# 35727            ...    ...    ...    ...    ...        ...      ...     ...     ...       ...
# 53589            ...    ...    ...    ...    ...        ...      ...     ...     ...       ...
# Dask Name: from_pandas, 1 graph layer

# %%
report_dd2.head()
# Out:
#    Day  Month  Year  Cases  Deaths  Population      Rate      Country Code  \
# 0    5     11  2020    121       6    38041757  3.745884  Afghanistan  AFG
# 1    4     11  2020     86       4    38041757  3.782685  Afghanistan  AFG
# 2    3     11  2020     95       3    38041757  3.787943  Afghanistan  AFG
# 3    2     11  2020    132       5    38041757  3.766913  Afghanistan  AFG
# 4    1     11  2020     76       0    38041757  3.575019  Afghanistan  AFG
#
#   Continent
# 0      Asia
# 1      Asia
# 2      Asia
# 3      Asia
# 4      Asia

# %%
report_dd2.tail()
# Out:
#        Day  Month  Year  Cases  Deaths  Population  Rate   Country Code  \
# 53585   25      3  2020      0       0    14645473   0.0  Zimbabwe  ZWE
# 53586   24      3  2020      0       1    14645473   0.0  Zimbabwe  ZWE
# 53587   23      3  2020      0       0    14645473   0.0  Zimbabwe  ZWE
# 53588   22      3  2020      1       0    14645473   0.0  Zimbabwe  ZWE
# 53589   21      3  2020      1       0    14645473   0.0  Zimbabwe  ZWE
#
#       Continent
# 53585    Africa
# 53586    Africa
# 53587    Africa
# 53588    Africa
# 53589    Africa

# %% [markdown]
# ## What do you think the following returns and why?
# Remember Ray

# %%
report_dd2['Rate'].max()
# Out:
# dd.Scalar<series-..., dtype=float64>

# %% [markdown]
# ### And just like Ray, we can evaluate and get a result

# %%
report_dd2['Rate'].max().compute()
# Out:
# 1900.83621

# %% [markdown]
# **So what is this doing behind the scenes?**
#
# <img src="https://camo.githubusercontent.com/349ed6d3048da7d324ef6fa8b07f66f5072ad2eb/687474703a2f2f6461736b2e7079646174612e6f72672f656e2f6c61746573742f5f696d616765732f6461736b2d646174616672616d652e737667" width=400>

# %% [markdown]
# Let's assume our dataset was large enough that finding the mean took some time. Let's also assume we aren't 100% sure what we want to calculate. We need to be able to quickly experiment with a dataset that "can't" fit into memory. This is where Dask can really shine. Think of Dask if:
# * You are already using Pandas
# * Your data may or may not fit into memory
# * You want to make better use of distributed computing (i.e., cores or processors)

# %% [markdown]
# **Example: Calculate the mean rate for each country**

# %%
report_dd2.groupby('Country')['Rate'].mean()
# Out:
# Dask Series Structure:
# npartitions=1
#     float64
#         ...
# Name: Rate, dtype: float64
# Dask Name: truediv, 7 graph layers

# %%
country_means = report_dd2.groupby('Country')['Rate'].mean().compute()
country_means_df = country_means.sort_values(ascending=False).to_frame()
country_means_df
# Out:
#                                                   Rate
# Country
# Andorra                                     342.905588
# Aruba                                       255.999914
# Bahrain                                     222.996526
# Qatar                                       212.499388
# Holy_See                                    180.409691
# ...                                                ...
# United_Republic_of_Tanzania                   0.051734
# Laos                                          0.014750
# Marshall_Islands                              0.000000
# Wallis_and_Futuna                             0.000000
# Cases_on_an_international_conveyance_Japan    0.000000
#
# [213 rows x 1 columns]

# %% [markdown]
# I want to merge the continent back into the analysis

# %%
continent_group = report_dd2.groupby('Country')['Continent'].apply(lambda s: s.iloc[0], meta="").compute()
continent_group_df = continent_group.sort_values(ascending=False).to_frame()
continent_group_df.columns = ["Continent"]
continent_group_df
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/core.py:7077: FutureWarning: Meta is not valid, `map_partitions` and `map_overlap` expects output to be a pandas object. Try passing a pandas object as meta or a dict or tuple representing the (name, dtype) of the columns. In the future the meta you passed will not work.
#   warnings.warn(
#                                            Continent
# Country
# Cases_on_an_international_conveyance_Japan     Other
# Northern_Mariana_Islands                     Oceania
# Wallis_and_Futuna                            Oceania
# Australia                                    Oceania
# Marshall_Islands                             Oceania
# ...                                              ...
# Lesotho                                       Africa
# Eswatini                                      Africa
# Malawi                                        Africa
# Mauritius                                     Africa
# Kenya                                         Africa
#
# [213 rows x 1 columns]

# %% [markdown]
# * ``apply`` is a function that will apply a function of our specification to each object. It's basically a for loop
# * ``meta`` is a Dask parameter that is needed because we are running a custom function. This tells Dask we are planning on returning a string.
# * ``lambda`` is a Python anonymous function.

# %% [markdown]
# Note: Both ``continent_group_df`` and ``continent_means_df`` have the same index, so we can join them, and then reset the index. The right mindset to get into in Pandas is to think like a database.

# %%
plot_df = country_means_df.join(continent_group_df).reset_index()
plot_df
# Out:
#                                         Country        Rate Continent
# 0                                       Andorra  342.905588    Europe
# 1                                         Aruba  255.999914   America
# 2                                       Bahrain  222.996526      Asia
# 3                                         Qatar  212.499388      Asia
# 4                                      Holy_See  180.409691    Europe
# ..                                          ...         ...       ...
# 208                 United_Republic_of_Tanzania    0.051734    Africa
# 209                                        Laos    0.014750      Asia
# 210                            Marshall_Islands    0.000000   Oceania
# 211                           Wallis_and_Futuna    0.000000   Oceania
# 212  Cases_on_an_international_conveyance_Japan    0.000000     Other
#
# [213 rows x 3 columns]

# %%
import altair as alt
g=alt.Chart(plot_df).mark_bar().encode(
    y='Country',
    x='Rate',
    color='Continent',
    row='Continent'
)

# %%
g
# Out:
# alt.Chart(...)

# %% [markdown]
# That's a lot and basically a great big mess. What if we want to radically change the algorithm and calculation? This is where a good distributed framework can start to pay off.
# * Running something one time in a serial manner is often ok.
# * We almost never need to run something a single time.
# * More than not development is going to take 100's of iterations before we are happy with our results.
# * Strategy: prototype on small datasets, and use a flexible and easy to use distributed system

# %% [markdown]
# ## Wrapping up
# There is much more to Ray and Dask than we presented in this chapter. They are both flexible and wonderful additions to the Python language. You can get a long way with these two libraries without leaving the comfort of a language you know. But in both cases, you need to be aware you are executing your programs in a distributed manner and structure them accordingly or you will not see the benefits.

# %% [markdown]
# ## Questions
#
# ### 1. What is a decorator and what do we use them in Ray to accomplish?
#
#
# ### 2. Can you call a function that has a Ray decorator in the normal Python way?
#
#
# ### 3. Explain what futures are in Ray and why they are important?
#
#
# ### 4. How would you compare Ray and Dask?
#
#
# ### 5. Does Dask use futures? How do you compare them to Ray futures? How do you tell Dask to execute and produce a result?
#
#
# **Thank you!**
